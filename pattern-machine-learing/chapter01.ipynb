# %% [markdown]
# # 01. 简介
# 机器学习是近年来最激动人心的技术和最具前景的技术，机器学习已经应用到生活中的各个方面，比如当使用搜索引擎时，学习算法学会如何快速对结果分类和排序。在社交应用中，自动识别出朋友的照片。当阅读电子邮件时，可以过滤大量垃圾邮件。
# 机器学习成为一种新的学习领域，应用前景非常的广阔，诸如，*Web click data,medical records,biology,engineering*
#
# ## 01.1. 机器学习定义
